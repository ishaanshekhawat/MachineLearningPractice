# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# Two Types of Tensors:
#
#
# 1.   Constant
# 2.   Variable

# %% [markdown]
# ***tf.constant()***
# <br>Tensors created in this way are immutable

# %%
ta = tf.constant(49)
ta
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=49>

# %%
ta.shape
# Out:
# TensorShape([])

# %%
ta.dtype
# Out:
# tf.int32

# %%
tb = tf.constant([[2.,5.],[9.,4.]])
tb
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 5.],
#        [9., 4.]], dtype=float32)>

# %%
tb.shape
# Out:
# TensorShape([2, 2])

# %%
tb.dtype
# Out:
# tf.float32

# %% [markdown]
# **Subsetting tensor**

# %%
tb
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 5.],
#        [9., 4.]], dtype=float32)>

# %%
tb[:,1]
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([5., 4.], dtype=float32)>

# %%
tb[0,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([2., 5.], dtype=float32)>

# %% [markdown]
# **Mathematical Operations**

# %%
ta+4
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=53>

# %%
tb
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 5.],
#        [9., 4.]], dtype=float32)>

# %%
tf.transpose(tb)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 9.],
#        [5., 4.]], dtype=float32)>

# %% [markdown]
# Matrix Multiplication

# %%
tc = tf.constant([[3.,4.],[7.,9.],[0.,2.]])
tc
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[3., 4.],
#        [7., 9.],
#        [0., 2.]], dtype=float32)>

# %%
tc @ tb
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[42., 31.],
#        [95., 71.],
#        [18.,  8.]], dtype=float32)>

# %% [markdown]
# Calculations

# %%
tf.reduce_sum(tc)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=25.0>

# %%
tf.reduce_mean(tc)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=4.166666507720947>

# %%
tf.reduce_max(tc)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.0>

# %% [markdown]
# Some Maths

# %%
tf.math.log(tc)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[1.0986123, 1.3862944],
#        [1.9459102, 2.1972246],
#        [     -inf, 0.6931472]], dtype=float32)>

# %%
tf.math.exp(tc)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[2.0085537e+01, 5.4598148e+01],
#        [1.0966332e+03, 8.1030840e+03],
#        [1.0000000e+00, 7.3890562e+00]], dtype=float32)>

# %% [markdown]
# **Type Conversions**

# %%
ta
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=49>

# %%
td = tf.constant(57.4)
td
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=57.400001525878906>

# %%
ta + td
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-23-8004fe10ae8e> in <cell line: 0>()
# ----> 1 ta + td
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6000 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6001   e.message += (" name: " + str(name if name is not None else ""))
# -> 6002   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    6003
#    6004
#
# InvalidArgumentError: cannot compute AddV2 as input #1(zero-based) was expected to be a int32 tensor but is a float tensor [Op:AddV2] name:

# %%
td +  tf.cast(ta, tf.float32)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=106.4000015258789>

# %% [markdown]
# ***tf.Variable()***
# <BR>Variables created in this way, are mutable and can be used to implement weights in neural networks

# %%
va = tf.Variable([[22.,35.,59.],[45.,98.,23.]])
va
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[22., 35., 59.],
#        [45., 98., 23.]], dtype=float32)>

# %% [markdown]
# *tf.Variable* can perform same operations as *tf.Tensor* <BR>It has also some functions like *assign()*, *assign_add()* etc.

# %%
va.assign(3*va)
va
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[ 66., 105., 177.],
#        [135., 294.,  69.]], dtype=float32)>

# %% [markdown]
# Trying it with constant tensor

# %%
tc = tf.constant([[3.,4.],[7.,9.],[0.,2.]])
tc
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[3., 4.],
#        [7., 9.],
#        [0., 2.]], dtype=float32)>

# %%
tc.assign(3*tc)
tc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-28e53733910d> in <cell line: 0>()
# ----> 1 tc.assign(3*tc)
#       2 tc
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor.py in __getattr__(self, name)
#     258         tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259       """)
# --> 260     self.__getattribute__(name)
#     261
#     262   @property
#
# AttributeError: 'tensorflow.python.framework.ops.EagerTensor' object has no attribute 'assign'

# %% [markdown]
# ###Custom Loop

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
x = np.linspace(-2,2, 20)
def f(x):
  return x * 3.0 + 5.0
y = f(x)

# %%
initial_w = 0.1
initial_b = 0.3
class Model(tf.Module):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)
    # In practice, these should be randomly initialized
    self.w = tf.Variable(initial_w)
    self.b = tf.Variable(initial_b)

  def __call__(self, x):
    return self.w * x + self.b

model = Model()

# %%
def loss(predicted_y, actual_y):
  return tf.reduce_mean(tf.square(predicted_y - actual_y))

x = tf.convert_to_tensor(x, dtype=tf.float32)
y = tf.convert_to_tensor(y, dtype=tf.float32)

# %%
def train(model, inputs, outputs, learning_rate):
  with tf.GradientTape() as t:
    current_loss = loss(model(inputs),outputs)
  dw, db = t.gradient(current_loss, [model.w, model.b])
  model.w.assign_sub(learning_rate * dw)
  model.b.assign_sub(learning_rate * db)
  return current_loss;

# %%
model = Model()

list_w = []
list_b = []
losses = []
for epoch in range(30):
  list_w.append(model.w.numpy())
  list_b.append(model.b.numpy())
  current_loss = train(model, x, y, learning_rate=0.1)
  losses.append(current_loss)
  print('Epoch %2d: w=%1.2f b=%1.2f, loss=%2.5f' % (epoch,model.w.numpy(),model.b.numpy(),current_loss))
# Out:
# Epoch  0: w=0.95 b=1.24, loss=34.48368
# Epoch  1: w=1.56 b=1.99, loss=20.30217
# Epoch  2: w=1.98 b=2.59, loss=12.11430
# Epoch  3: w=2.28 b=3.07, loss=7.31589
# Epoch  4: w=2.49 b=3.46, loss=4.46468
# Epoch  5: w=2.64 b=3.77, loss=2.74922
# Epoch  6: w=2.75 b=4.01, loss=1.70569
# Epoch  7: w=2.82 b=4.21, loss=1.06488
# Epoch  8: w=2.87 b=4.37, loss=0.66821
# Epoch  9: w=2.91 b=4.50, loss=0.42103
# Epoch 10: w=2.94 b=4.60, loss=0.26617
# Epoch 11: w=2.96 b=4.68, loss=0.16871
# Epoch 12: w=2.97 b=4.74, loss=0.10716
# Epoch 13: w=2.98 b=4.79, loss=0.06818
# Epoch 14: w=2.98 b=4.83, loss=0.04343
# Epoch 15: w=2.99 b=4.87, loss=0.02770
# Epoch 16: w=2.99 b=4.89, loss=0.01768
# Epoch 17: w=2.99 b=4.92, loss=0.01129
# Epoch 18: w=3.00 b=4.93, loss=0.00721
# Epoch 19: w=3.00 b=4.95, loss=0.00461
# Epoch 20: w=3.00 b=4.96, loss=0.00295
# Epoch 21: w=3.00 b=4.97, loss=0.00188
# Epoch 22: w=3.00 b=4.97, loss=0.00121
# Epoch 23: w=3.00 b=4.98, loss=0.00077
# Epoch 24: w=3.00 b=4.98, loss=0.00049
# Epoch 25: w=3.00 b=4.99, loss=0.00032
# Epoch 26: w=3.00 b=4.99, loss=0.00020
# Epoch 27: w=3.00 b=4.99, loss=0.00013
# Epoch 28: w=3.00 b=4.99, loss=0.00008
# Epoch 29: w=3.00 b=4.99, loss=0.00005

# %%
x = np.linspace(-2,2, 20)
def f(x):
  return x * 3.0 + 5.0
y = f(x)

# %%
x.shape
# Out:
# (20,)

# %%
x
# Out:
# array([-2.        , -1.78947368, -1.57894737, -1.36842105, -1.15789474,
#        -0.94736842, -0.73684211, -0.52631579, -0.31578947, -0.10526316,
#         0.10526316,  0.31578947,  0.52631579,  0.73684211,  0.94736842,
#         1.15789474,  1.36842105,  1.57894737,  1.78947368,  2.        ])

# %%
x = x.reshape(-1,1)
x.shape
# Out:
# (20, 1)

# %%
x.shape[1]
# Out:
# 1

# %% [markdown]
# #### Model Definition

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(x.shape[1],)),
    tf.keras.layers.Dense(1, kernel_initializer=tf.keras.initializers.LecunNormal(seed=25),
                          bias_initializer=tf.keras.initializers.Zeros())
])
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-797352081.py in <cell line: 0>()
#       1 model = tf.keras.models.Sequential([
# ----> 2     tf.keras.layers.Input(shape=(x.shape[1],)),
#       3     tf.keras.layers.Dense(1, kernel_initializer=tf.keras.initializers.LecunNormal(seed=25),
#       4                           bias_initializer=tf.keras.initializers.Zeros(),
#       5                           activation='sigmoid')
#
# NameError: name 'x' is not defined

# %%
model.get_weights()
# Out:
# [array([[-0.6726856]], dtype=float32), array([0.], dtype=float32)]

# %%
#model.compile(optimizer='sgd', loss='mean_squared_error',metrics=['mae'])

# %%
#model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.5), loss='mean_squared_error',metrics=['mae'])

# %%
#model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.5,nesterov=True),
# loss='mean_squared_error',metrics=['mae'])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
  loss='mean_squared_error',metrics=['mae'])

# %%
history = model.fit( x,y,verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 1/1 - 1s - 669ms/step - loss: 42.8285 - mae: 5.3485
# Epoch 2/100
# 1/1 - 0s - 38ms/step - loss: 42.6254 - mae: 5.3361
# Epoch 3/100
# 1/1 - 0s - 55ms/step - loss: 42.4228 - mae: 5.3237
# Epoch 4/100
# 1/1 - 0s - 56ms/step - loss: 42.2208 - mae: 5.3114
# Epoch 5/100
# 1/1 - 0s - 36ms/step - loss: 42.0193 - mae: 5.2990
# Epoch 6/100
# 1/1 - 0s - 56ms/step - loss: 41.8183 - mae: 5.2866
# Epoch 7/100
# 1/1 - 0s - 61ms/step - loss: 41.6178 - mae: 5.2743
# Epoch 8/100
# 1/1 - 0s - 57ms/step - loss: 41.4179 - mae: 5.2619
# Epoch 9/100
# 1/1 - 0s - 36ms/step - loss: 41.2186 - mae: 5.2496
# Epoch 10/100
# 1/1 - 0s - 36ms/step - loss: 41.0198 - mae: 5.2372
# Epoch 11/100
# 1/1 - 0s - 37ms/step - loss: 40.8216 - mae: 5.2249
# Epoch 12/100
# 1/1 - 0s - 58ms/step - loss: 40.6240 - mae: 5.2125
# Epoch 13/100
# 1/1 - 0s - 38ms/step - loss: 40.4269 - mae: 5.2002
# Epoch 14/100
# 1/1 - 0s - 58ms/step - loss: 40.2305 - mae: 5.1879
# Epoch 15/100
# 1/1 - 0s - 59ms/step - loss: 40.0346 - mae: 5.1756
# Epoch 16/100
# 1/1 - 0s - 55ms/step - loss: 39.8394 - mae: 5.1632
# Epoch 17/100
# 1/1 - 0s - 55ms/step - loss: 39.6448 - mae: 5.1509
# Epoch 18/100
# 1/1 - 0s - 51ms/step - loss: 39.4508 - mae: 5.1386
# Epoch 19/100
# 1/1 - 0s - 63ms/step - loss: 39.2574 - mae: 5.1264
# Epoch 20/100
# 1/1 - 0s - 134ms/step - loss: 39.0646 - mae: 5.1141
# Epoch 21/100
# 1/1 - 0s - 137ms/step - loss: 38.8725 - mae: 5.1018
# Epoch 22/100
# 1/1 - 0s - 139ms/step - loss: 38.6810 - mae: 5.0895
# Epoch 23/100
# 1/1 - 0s - 133ms/step - loss: 38.4902 - mae: 5.0773
# Epoch 24/100
# 1/1 - 0s - 137ms/step - loss: 38.3000 - mae: 5.0651
# Epoch 25/100
# 1/1 - 0s - 57ms/step - loss: 38.1104 - mae: 5.0528
# Epoch 26/100
# 1/1 - 0s - 51ms/step - loss: 37.9215 - mae: 5.0406
# Epoch 27/100
# 1/1 - 0s - 55ms/step - loss: 37.7333 - mae: 5.0284
# Epoch 28/100
# 1/1 - 0s - 60ms/step - loss: 37.5457 - mae: 5.0162
# Epoch 29/100
# 1/1 - 0s - 57ms/step - loss: 37.3588 - mae: 5.0040
# Epoch 30/100
# 1/1 - 0s - 55ms/step - loss: 37.1725 - mae: 4.9918
# Epoch 31/100
# 1/1 - 0s - 64ms/step - loss: 36.9870 - mae: 4.9797
# Epoch 32/100
# 1/1 - 0s - 65ms/step - loss: 36.8021 - mae: 4.9675
# Epoch 33/100
# 1/1 - 0s - 61ms/step - loss: 36.6178 - mae: 4.9554
# Epoch 34/100
# 1/1 - 0s - 64ms/step - loss: 36.4343 - mae: 4.9433
# Epoch 35/100
# 1/1 - 0s - 56ms/step - loss: 36.2514 - mae: 4.9312
# Epoch 36/100
# 1/1 - 0s - 137ms/step - loss: 36.0692 - mae: 4.9191
# Epoch 37/100
# 1/1 - 0s - 63ms/step - loss: 35.8876 - mae: 4.9070
# Epoch 38/100
# 1/1 - 0s - 78ms/step - loss: 35.7068 - mae: 4.8949
# Epoch 39/100
# 1/1 - 0s - 57ms/step - loss: 35.5266 - mae: 4.8828
# Epoch 40/100
# 1/1 - 0s - 123ms/step - loss: 35.3471 - mae: 4.8708
# Epoch 41/100
# 1/1 - 0s - 57ms/step - loss: 35.1683 - mae: 4.8588
# Epoch 42/100
# 1/1 - 0s - 37ms/step - loss: 34.9901 - mae: 4.8468
# Epoch 43/100
# 1/1 - 0s - 59ms/step - loss: 34.8127 - mae: 4.8348
# Epoch 44/100
# 1/1 - 0s - 35ms/step - loss: 34.6359 - mae: 4.8228
# Epoch 45/100
# 1/1 - 0s - 57ms/step - loss: 34.4598 - mae: 4.8108
# Epoch 46/100
# 1/1 - 0s - 59ms/step - loss: 34.2844 - mae: 4.7988
# Epoch 47/100
# 1/1 - 0s - 37ms/step - loss: 34.1097 - mae: 4.7869
# Epoch 48/100
# 1/1 - 0s - 54ms/step - loss: 33.9356 - mae: 4.7750
# Epoch 49/100
# 1/1 - 0s - 57ms/step - loss: 33.7622 - mae: 4.7630
# Epoch 50/100
# 1/1 - 0s - 33ms/step - loss: 33.5895 - mae: 4.7511
# Epoch 51/100
# 1/1 - 0s - 37ms/step - loss: 33.4175 - mae: 4.7393
# Epoch 52/100
# 1/1 - 0s - 34ms/step - loss: 33.2462 - mae: 4.7274
# Epoch 53/100
# 1/1 - 0s - 34ms/step - loss: 33.0755 - mae: 4.7155
# Epoch 54/100
# 1/1 - 0s - 39ms/step - loss: 32.9055 - mae: 4.7037
# Epoch 55/100
# 1/1 - 0s - 35ms/step - loss: 32.7362 - mae: 4.6919
# Epoch 56/100
# 1/1 - 0s - 62ms/step - loss: 32.5676 - mae: 4.6801
# Epoch 57/100
# 1/1 - 0s - 43ms/step - loss: 32.3996 - mae: 4.6683
# Epoch 58/100
# 1/1 - 0s - 57ms/step - loss: 32.2323 - mae: 4.6565
# Epoch 59/100
# 1/1 - 0s - 34ms/step - loss: 32.0657 - mae: 4.6447
# Epoch 60/100
# 1/1 - 0s - 58ms/step - loss: 31.8997 - mae: 4.6330
# Epoch 61/100
# 1/1 - 0s - 58ms/step - loss: 31.7344 - mae: 4.6213
# Epoch 62/100
# 1/1 - 0s - 59ms/step - loss: 31.5698 - mae: 4.6095
# Epoch 63/100
# 1/1 - 0s - 40ms/step - loss: 31.4058 - mae: 4.5978
# Epoch 64/100
# 1/1 - 0s - 35ms/step - loss: 31.2425 - mae: 4.5862
# Epoch 65/100
# 1/1 - 0s - 57ms/step - loss: 31.0799 - mae: 4.5745
# Epoch 66/100
# 1/1 - 0s - 58ms/step - loss: 30.9179 - mae: 4.5628
# Epoch 67/100
# 1/1 - 0s - 35ms/step - loss: 30.7566 - mae: 4.5512
# Epoch 68/100
# 1/1 - 0s - 57ms/step - loss: 30.5959 - mae: 4.5396
# Epoch 69/100
# 1/1 - 0s - 34ms/step - loss: 30.4359 - mae: 4.5280
# Epoch 70/100
# 1/1 - 0s - 58ms/step - loss: 30.2766 - mae: 4.5164
# Epoch 71/100
# 1/1 - 0s - 58ms/step - loss: 30.1179 - mae: 4.5048
# Epoch 72/100
# 1/1 - 0s - 57ms/step - loss: 29.9599 - mae: 4.4932
# Epoch 73/100
# 1/1 - 0s - 57ms/step - loss: 29.8025 - mae: 4.4817
# Epoch 74/100
# 1/1 - 0s - 58ms/step - loss: 29.6457 - mae: 4.4702
# Epoch 75/100
# 1/1 - 0s - 66ms/step - loss: 29.4897 - mae: 4.4587
# Epoch 76/100
# 1/1 - 0s - 35ms/step - loss: 29.3342 - mae: 4.4472
# Epoch 77/100
# 1/1 - 0s - 57ms/step - loss: 29.1794 - mae: 4.4357
# Epoch 78/100
# 1/1 - 0s - 33ms/step - loss: 29.0253 - mae: 4.4242
# Epoch 79/100
# 1/1 - 0s - 36ms/step - loss: 28.8717 - mae: 4.4128
# Epoch 80/100
# 1/1 - 0s - 38ms/step - loss: 28.7189 - mae: 4.4014
# Epoch 81/100
# 1/1 - 0s - 56ms/step - loss: 28.5666 - mae: 4.3899
# Epoch 82/100
# 1/1 - 0s - 58ms/step - loss: 28.4150 - mae: 4.3785
# Epoch 83/100
# 1/1 - 0s - 36ms/step - loss: 28.2641 - mae: 4.3672
# Epoch 84/100
# 1/1 - 0s - 58ms/step - loss: 28.1137 - mae: 4.3558
# Epoch 85/100
# 1/1 - 0s - 36ms/step - loss: 27.9640 - mae: 4.3444
# Epoch 86/100
# 1/1 - 0s - 56ms/step - loss: 27.8149 - mae: 4.3331
# Epoch 87/100
# 1/1 - 0s - 37ms/step - loss: 27.6665 - mae: 4.3218
# Epoch 88/100
# 1/1 - 0s - 56ms/step - loss: 27.5187 - mae: 4.3105
# Epoch 89/100
# 1/1 - 0s - 57ms/step - loss: 27.3715 - mae: 4.2992
# Epoch 90/100
# 1/1 - 0s - 58ms/step - loss: 27.2249 - mae: 4.2879
# Epoch 91/100
# 1/1 - 0s - 62ms/step - loss: 27.0790 - mae: 4.2767
# Epoch 92/100
# 1/1 - 0s - 40ms/step - loss: 26.9336 - mae: 4.2654
# Epoch 93/100
# 1/1 - 0s - 58ms/step - loss: 26.7889 - mae: 4.2542
# Epoch 94/100
# 1/1 - 0s - 60ms/step - loss: 26.6448 - mae: 4.2430
# Epoch 95/100
# 1/1 - 0s - 51ms/step - loss: 26.5013 - mae: 4.2318
# Epoch 96/100
# 1/1 - 0s - 39ms/step - loss: 26.3585 - mae: 4.2207
# Epoch 97/100
# 1/1 - 0s - 37ms/step - loss: 26.2162 - mae: 4.2095
# Epoch 98/100
# 1/1 - 0s - 58ms/step - loss: 26.0746 - mae: 4.1984
# Epoch 99/100
# 1/1 - 0s - 58ms/step - loss: 25.9335 - mae: 4.1872
# Epoch 100/100
# 1/1 - 0s - 41ms/step - loss: 25.7931 - mae: 4.1761

# %%
model.get_weights()
# Out:
# [array([[0.37526163]], dtype=float32), array([1.0629072], dtype=float32)]
