# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from tqdm import tqdm
from sklearn.metrics import log_loss, accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer, make_column_selector
import os

# %%
vehicle = pd.read_csv("D:/Training/Academy/ML(Python)/Cases/Vehicle Silhouettes/Vehicle.csv")
X, y = vehicle.drop('Class', axis=1), vehicle['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25,
                                                   stratify=y)

# %% [markdown]
# w/o scaling

# %%
svm = SVC(kernel="linear")
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8464566929133859

# %%
svm = SVC(kernel="linear", decision_function_shape='ovo')
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8464566929133859

# %%
std_scaler = StandardScaler()
Cs = np.linspace(0.01, 5, 15)
dfs = ['ovo','ovr']
scores = []
for c in Cs:
    for s in dfs:
        svm = SVC(kernel='linear', C=c, decision_function_shape=s)
        pipe = Pipeline([('SCL', std_scaler), ('SVM', svm)])
        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)
        scores.append([c,s, accuracy_score(y_test, y_pred)])
df_scores = pd.DataFrame( scores, columns=['C','decision','score'] )
df_scores.sort_values('score', ascending=False)
# Out:
#            C decision     score
# 25  4.287143      ovr  0.842520
# 24  4.287143      ovo  0.842520
# 9   1.435714      ovr  0.838583
# 17  2.861429      ovr  0.838583
# 16  2.861429      ovo  0.838583
# 22  3.930714      ovo  0.838583
# 23  3.930714      ovr  0.838583
# 8   1.435714      ovo  0.838583
# 12  2.148571      ovo  0.834646
# 14  2.505000      ovo  0.834646
# 13  2.148571      ovr  0.834646
# 15  2.505000      ovr  0.834646
# 11  1.792143      ovr  0.834646
# 10  1.792143      ovo  0.834646
# 20  3.574286      ovo  0.834646
# 26  4.643571      ovo  0.834646
# 27  4.643571      ovr  0.834646
# 21  3.574286      ovr  0.834646
# 28  5.000000      ovo  0.830709
# 29  5.000000      ovr  0.830709
# 19  3.217857      ovr  0.830709
# 18  3.217857      ovo  0.830709
# 5   0.722857      ovr  0.822835
# 4   0.722857      ovo  0.822835
# 7   1.079286      ovr  0.818898
# 6   1.079286      ovo  0.818898
# 3   0.366429      ovr  0.807087
# 2   0.366429      ovo  0.807087
# 1   0.010000      ovr  0.704724
# 0   0.010000      ovo  0.704724

# %% [markdown]
# #### Polynomial Kernel

# %%
Cs = np.linspace(0.01, 5, 10)
deg = [2,3,4]
dfs = ['ovo','ovr']
scores = []
for d in tqdm(deg):
    for c in Cs:
        for s in dfs:
            svm = SVC(kernel='poly', C=c, degree=d , decision_function_shape=s)
            pipe = Pipeline([('SCL', std_scaler), ('SVM', svm)])
            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            scores.append([c,s, d, accuracy_score(y_test, y_pred)])
df_scores = pd.DataFrame( scores, columns=['C', 'decision','degree' ,'score'] )
df_scores.sort_values('score', ascending=False)
# Out:
# 100%|██████████| 3/3 [00:01<00:00,  2.49it/s]
#            C decision  degree     score
# 39  5.000000      ovr       3  0.791339
# 38  5.000000      ovo       3  0.791339
# 36  4.445556      ovo       3  0.771654
# 37  4.445556      ovr       3  0.771654
# 34  3.891111      ovo       3  0.763780
# 35  3.891111      ovr       3  0.763780
# 33  3.336667      ovr       3  0.759843
# 32  3.336667      ovo       3  0.759843
# 31  2.782222      ovr       3  0.751969
# 29  2.227778      ovr       3  0.751969
# 28  2.227778      ovo       3  0.751969
# 30  2.782222      ovo       3  0.751969
# 23  0.564444      ovr       3  0.736220
# 22  0.564444      ovo       3  0.736220
# 27  1.673333      ovr       3  0.736220
# 26  1.673333      ovo       3  0.736220
# 17  4.445556      ovr       2  0.736220
# 16  4.445556      ovo       2  0.736220
# 15  3.891111      ovr       2  0.732283
# 18  5.000000      ovo       2  0.732283
# 19  5.000000      ovr       2  0.732283
# 14  3.891111      ovo       2  0.732283
# 8   2.227778      ovo       2  0.724409
# 11  2.782222      ovr       2  0.724409
# 9   2.227778      ovr       2  0.724409
# 10  2.782222      ovo       2  0.724409
# 13  3.336667      ovr       2  0.720472
# 12  3.336667      ovo       2  0.720472
# 24  1.118889      ovo       3  0.716535
# 25  1.118889      ovr       3  0.716535
# 7   1.673333      ovr       2  0.692913
# 6   1.673333      ovo       2  0.692913
# 56  4.445556      ovo       4  0.661417
# 57  4.445556      ovr       4  0.661417
# 58  5.000000      ovo       4  0.661417
# 59  5.000000      ovr       4  0.661417
# 4   1.118889      ovo       2  0.661417
# 5   1.118889      ovr       2  0.661417
# 55  3.891111      ovr       4  0.653543
# 54  3.891111      ovo       4  0.653543
# 53  3.336667      ovr       4  0.649606
# 52  3.336667      ovo       4  0.649606
# 47  1.673333      ovr       4  0.645669
# 46  1.673333      ovo       4  0.645669
# 49  2.227778      ovr       4  0.641732
# 48  2.227778      ovo       4  0.641732
# 50  2.782222      ovo       4  0.637795
# 51  2.782222      ovr       4  0.637795
# 44  1.118889      ovo       4  0.633858
# 45  1.118889      ovr       4  0.633858
# 3   0.564444      ovr       2  0.622047
# 2   0.564444      ovo       2  0.622047
# 43  0.564444      ovr       4  0.531496
# 42  0.564444      ovo       4  0.531496
# 41  0.010000      ovr       4  0.381890
# 40  0.010000      ovo       4  0.381890
# 1   0.010000      ovr       2  0.377953
# 0   0.010000      ovo       2  0.377953
# 21  0.010000      ovr       3  0.346457
# 20  0.010000      ovo       3  0.346457

# %% [markdown]
# #### Radial Kernel

# %%
Cs = np.linspace(0.01, 5, 10)
Gs = np.linspace(0.01, 5, 10)
dfs = ['ovo','ovr']
scores = []
for g in tqdm(Gs):
    for c in Cs:
        for s in dfs:
            svm = SVC(kernel='rbf', C=c, gamma=g , decision_function_shape=s)
            pipe = Pipeline([('SCL', std_scaler), ('SVM', svm)])
            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            scores.append([c,s, g, accuracy_score(y_test, y_pred)])
df_scores = pd.DataFrame( scores, columns=['C', 'decision','gamma' ,'score'] )
df_scores.sort_values('score', ascending=False)
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
#             C decision     gamma     score
# 19   5.000000      ovr  0.010000  0.779528
# 18   5.000000      ovo  0.010000  0.779528
# 16   4.445556      ovo  0.010000  0.771654
# 17   4.445556      ovr  0.010000  0.771654
# 15   3.891111      ovr  0.010000  0.763780
# ..        ...      ...       ...       ...
# 140  0.010000      ovo  3.891111  0.255906
# 141  0.010000      ovr  3.891111  0.255906
# 160  0.010000      ovo  4.445556  0.255906
# 161  0.010000      ovr  4.445556  0.255906
# 100  0.010000      ovo  2.782222  0.255906
#
# [200 rows x 4 columns]

# %% [markdown]
# #### Glass Identification

# %%
os.chdir("D:/Training/Academy/ML(Python)/Cases/Glass_Identification")
glass = pd.read_csv("Glass.csv")
X, y = glass.drop('Type', axis=1), glass['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25,
                                                   stratify=y)

# %%
std_scaler = StandardScaler()
Cs = np.linspace(0.01, 5, 15)
dfs = ['ovo','ovr']
scores = []
for c in Cs:
    for s in dfs:
        svm = SVC(kernel='linear', C=c, decision_function_shape=s)
        pipe = Pipeline([('SCL', std_scaler), ('SVM', svm)])
        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)
        scores.append([c,s, accuracy_score(y_test, y_pred)])
df_scores = pd.DataFrame( scores, columns=['C','decision','score'] )
df_scores.sort_values('score', ascending=False)
# Out:
#            C decision     score
# 29  5.000000      ovr  0.615385
# 26  4.643571      ovo  0.615385
# 2   0.366429      ovo  0.615385
# 3   0.366429      ovr  0.615385
# 28  5.000000      ovo  0.615385
# 27  4.643571      ovr  0.615385
# 22  3.930714      ovo  0.600000
# 21  3.574286      ovr  0.600000
# 20  3.574286      ovo  0.600000
# 19  3.217857      ovr  0.600000
# 18  3.217857      ovo  0.600000
# 17  2.861429      ovr  0.600000
# 16  2.861429      ovo  0.600000
# 25  4.287143      ovr  0.600000
# 12  2.148571      ovo  0.600000
# 13  2.148571      ovr  0.600000
# 24  4.287143      ovo  0.600000
# 11  1.792143      ovr  0.600000
# 10  1.792143      ovo  0.600000
# 9   1.435714      ovr  0.600000
# 8   1.435714      ovo  0.600000
# 5   0.722857      ovr  0.600000
# 4   0.722857      ovo  0.600000
# 23  3.930714      ovr  0.600000
# 15  2.505000      ovr  0.584615
# 14  2.505000      ovo  0.584615
# 7   1.079286      ovr  0.584615
# 6   1.079286      ovo  0.584615
# 1   0.010000      ovr  0.476923
# 0   0.010000      ovo  0.476923

# %% [markdown]
# ##### Polynomial

# %%
Cs = np.linspace(0.01, 5, 10)
deg = [2,3,4]
dfs = ['ovo','ovr']
scores = []
for d in tqdm(deg):
    for c in Cs:
        for s in dfs:
            svm = SVC(kernel='poly', C=c, degree=d , decision_function_shape=s)
            pipe = Pipeline([('SCL', std_scaler), ('SVM', svm)])
            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            scores.append([c,s, d, accuracy_score(y_test, y_pred)])
df_scores = pd.DataFrame( scores, columns=['C', 'decision','degree' ,'score'] )
df_scores.sort_values('score', ascending=False)
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  7.42it/s]
#            C decision  degree     score
# 14  3.891111      ovo       2  0.630769
# 15  3.891111      ovr       2  0.630769
# 19  5.000000      ovr       2  0.630769
# 18  5.000000      ovo       2  0.630769
# 17  4.445556      ovr       2  0.630769
# 16  4.445556      ovo       2  0.630769
# 10  2.782222      ovo       2  0.615385
# 11  2.782222      ovr       2  0.615385
# 12  3.336667      ovo       2  0.615385
# 13  3.336667      ovr       2  0.615385
# 8   2.227778      ovo       2  0.584615
# 9   2.227778      ovr       2  0.584615
# 6   1.673333      ovo       2  0.553846
# 7   1.673333      ovr       2  0.553846
# 30  2.782222      ovo       3  0.492308
# 31  2.782222      ovr       3  0.492308
# 39  5.000000      ovr       3  0.476923
# 38  5.000000      ovo       3  0.476923
# 37  4.445556      ovr       3  0.476923
# 36  4.445556      ovo       3  0.476923
# 35  3.891111      ovr       3  0.476923
# 34  3.891111      ovo       3  0.476923
# 33  3.336667      ovr       3  0.476923
# 32  3.336667      ovo       3  0.476923
# 55  3.891111      ovr       4  0.461538
# 56  4.445556      ovo       4  0.461538
# 57  4.445556      ovr       4  0.461538
# 58  5.000000      ovo       4  0.461538
# 54  3.891111      ovo       4  0.461538
# 59  5.000000      ovr       4  0.461538
# 5   1.118889      ovr       2  0.461538
# 28  2.227778      ovo       3  0.461538
# 27  1.673333      ovr       3  0.461538
# 26  1.673333      ovo       3  0.461538
# 25  1.118889      ovr       3  0.461538
# 24  1.118889      ovo       3  0.461538
# 29  2.227778      ovr       3  0.461538
# 4   1.118889      ovo       2  0.461538
# 50  2.782222      ovo       4  0.446154
# 46  1.673333      ovo       4  0.446154
# 49  2.227778      ovr       4  0.446154
# 53  3.336667      ovr       4  0.446154
# 51  2.782222      ovr       4  0.446154
# 52  3.336667      ovo       4  0.446154
# 48  2.227778      ovo       4  0.446154
# 22  0.564444      ovo       3  0.446154
# 23  0.564444      ovr       3  0.446154
# 47  1.673333      ovr       4  0.446154
# 45  1.118889      ovr       4  0.430769
# 44  1.118889      ovo       4  0.430769
# 42  0.564444      ovo       4  0.430769
# 3   0.564444      ovr       2  0.430769
# 2   0.564444      ovo       2  0.430769
# 43  0.564444      ovr       4  0.430769
# 21  0.010000      ovr       3  0.384615
# 20  0.010000      ovo       3  0.384615
# 1   0.010000      ovr       2  0.369231
# 41  0.010000      ovr       4  0.369231
# 40  0.010000      ovo       4  0.369231
# 0   0.010000      ovo       2  0.369231

# %% [markdown]
# ##### Radial

# %%
Cs = np.linspace(0.01, 5, 10)
Gs = np.linspace(0.01, 5, 10)
dfs = ['ovo','ovr']
scores = []
for g in tqdm(Gs):
    for c in Cs:
        for s in dfs:
            svm = SVC(kernel='rbf', C=c, gamma=g , decision_function_shape=s)
            pipe = Pipeline([('SCL', std_scaler), ('SVM', svm)])
            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            scores.append([c,s, g, accuracy_score(y_test, y_pred)])
df_scores = pd.DataFrame( scores, columns=['C', 'decision','gamma' ,'score'] )
df_scores.sort_values('score', ascending=False)
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  6.96it/s]
#             C decision     gamma     score
# 6    1.673333      ovo  0.010000  0.707692
# 7    1.673333      ovr  0.010000  0.707692
# 26   1.673333      ovo  0.564444  0.692308
# 27   1.673333      ovr  0.564444  0.692308
# 4    1.118889      ovo  0.010000  0.692308
# ..        ...      ...       ...       ...
# 121  0.010000      ovr  3.336667  0.353846
# 140  0.010000      ovo  3.891111  0.353846
# 141  0.010000      ovr  3.891111  0.353846
# 160  0.010000      ovo  4.445556  0.353846
# 100  0.010000      ovo  2.782222  0.353846
#
# [200 rows x 4 columns]
